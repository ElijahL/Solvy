# %%
import pandas as pd
from rdkit import Chem

# %%
esol_filepath = r"../data/raw/esol.csv"

# %%
esol_df = pd.read_csv(esol_filepath)
esol_df["mol"] = esol_df['SMILES'].apply(Chem.MolFromSmiles)
esol_df.head()
# Out:
#                                               SMILES  label  \
# 0  OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)...  -0.77
# 1                             Cc1occc1C(=O)Nc2ccccc2  -3.30
# 2                               CC(C)=CCCC(C)=CC(=O)  -2.06
# 3                 c1ccc2c(c1)ccc3c2ccc4c5ccccc5ccc43  -7.87
# 4                                            c1ccsc1  -1.33
#
#                                                 mol
# 0  <rdkit.Chem.rdchem.Mol object at 0x7fd139d4c7b0>
# 1  <rdkit.Chem.rdchem.Mol object at 0x7fd139d4c740>
# 2  <rdkit.Chem.rdchem.Mol object at 0x7fd139d4c6d0>
# 3  <rdkit.Chem.rdchem.Mol object at 0x7fd139d4c660>
# 4  <rdkit.Chem.rdchem.Mol object at 0x7fd139d4c5f0>
